# %% [markdown]
# # Notebook to Move final dcm files selected for processing to Project Folder

# %%
import shutil
import pickle
import pandas as pd
from l3finder.ingest import *
import os
import multiprocessing
from multiprocessing import get_context
from multiprocessing import set_start_method
from tqdm.notebook import tqdm
from investigate import *

# Custom functions
def save_object(obj, filename):
    with open(filename, 'wb') as output:  # Overwrites any existing file.
        pickle.dump(obj, output, pickle.HIGHEST_PROTOCOL)

def load_object(filename):        
    with open(filename, 'rb') as input:
        return pickle.load(input)

# %%
cwd = os.getcwd()
output = '/tf/pickles'

# %% [markdown]
# ### Open dataframes from both dumps and merge them after investigating duplicate cases

# %%
df_final1 = load_object(os.path.join(output,'df_final_dump_1.pkl'))
subjects1 = load_object(os.path.join(output,'subjects_final_dump_1.pkl'))

valid_subs = [s.id_ for s in subjects1]
df_final1 = df_final1[df_final1['ID'].isin(valid_subs)]

# %%
df_final2 = load_object(os.path.join(output,'df_final_dump_2.pkl'))
subjects2 = load_object(os.path.join(output,'subjects_final_dump_2.pkl'))
valid_subs = [s.id_ for s in subjects2]
display(df_final2[~df_final2['ID'].isin(valid_subs)])

df_final2 = df_final2[df_final2['ID'].isin(valid_subs)]
# Out:
#            ID Axial Sagittal Overlap  MissingScore PairValidity AxSlices  \
# 0    Z1396897  None     None    None           NaN         None     None
# 1    Z1041077  None     None    None           NaN         None     None
# 114   Z441008  None     None    None           NaN         None     None
# 304   Z525377  None     None    None           NaN         None     None
#
#     SagSlices  AxThick SagThick
# 0        None      NaN     None
# 1        None      NaN     None
# 114      None      NaN     None
# 304      None      NaN     None

# %%
print('Df_final1: ', len(df_final1))
print('subjects1: ', len(subjects1))
print('Df_final2: ', len(df_final2))
print('subjects2: ', len(subjects2))
# Out:
# Df_final1:  2052
# subjects1:  2052
# Df_final2:  377
# subjects2:  377

# %%
# Find overlap between Df_final1 and Df_final2
overlaps = df_final1.loc[df_final1['ID'].isin(df_final2['ID'].values),'ID'].values
print('No of overlaps: ',len(overlaps))
# Out:
# No of overlaps:  62

# %%
# print overlaps in 1
display(df_final1[df_final1['ID'].isin(overlaps)].sort_values(by='ID'))
# Out:
#             ID                                           Axial  \
# 29    Z1014113                        Z1014113-SE-2-Axial_Stnd
# 36    Z1017392                    Z1017392-SE-4-Axial_Body_5.0
# 44    Z1023089                    Z1023089-SE-2-Axial_Body_5.0
# 45    Z1024771                          Z1024771-SE-3-Body_5.0
# 57    Z1035204                    Z1035204-SE-5-Axial_Body_5.0
# 65    Z1041413             Z1041413-SE-4-Stnd_Pediatric_2.0_CE
# 114   Z1068362                      Z1068362-SE-3-KIDNEY_STONE
# 194   Z1140026                        Z1140026-SE-2-ABD_PELVIS
# 209   Z1154679                    Z1154679-SE-2-Axial_Body_5.0
# 217   Z1165230                                 Z1165230-SE-2-_
# 284   Z1203420                    Z1203420-SE-2-Axial_Body_5.0
# 296   Z1211258                                Z1211258-SE-6-AX
# 318   Z1224134                        Z1224134-SE-2-ABD_PELVIS
# 324   Z1225663                    Z1225663-SE-5-Axial_Body_5.0
# 428   Z1295431            Z1295431-SE-12-Axial_Bone_VOLUME_0.5
# 432   Z1300146         Z1300146-SE-4-Stnd_Pediatric_Axial_Stnd
# 437   Z1302641                          Z1302641-SE-2-2MM_ID_4
# 503   Z1347268            Z1347268-SE-4-Axial_Body_Axial_3.000
# 603   Z1437460             Z1437460-SE-3-Axial_Body_VOLUME_0.5
# 2051          Z995576-SE-9-Sagittal_Body_Sagittal_3.000    0.99         1.000
#
#      PairValidity AxSlices SagSlices  AxThick  SagThick
# 29          0.927      125        68     5.00      2.52
# 36              1       67        79     5.00         3
# 44          1.997       64        80     5.00         3
# 45          1.989       72        76     5.00         3
# 57          1.994       66        81     5.00         3
# 65          1.662      213       135     2.00         2
# 114          None      124      None     2.50      None
# 194             1      144       167     2.50         2
# 209         1.997       61        67     5.00         3
# 217         1.342       55       108     5.00       0.5
# 284         1.994       66        63     5.00         3
# 296          None      144      None     4.00      None
# 318         1.996      195       160     2.50         2
# 324         1.995       86        61     5.00         3
# 428             2      896        60     0.50         3
# 432          None      172      None     2.00      None
# 437         1.003      188        64     2.00         3
# 503         1.986       96        70     3.00         3
# 603         1.993     1152        65     0.50         3
# 606         1.995       84        42     5.00         3
# 633             2     1317        93     0.50         3
# 685         1.995       82        86     5.00         3
# 687         1.985       53        70     5.00         3
# 701         1.953       78        94     5.00         3
# 703         1.997     1344        60     0.50         3
# 710         1.991       85        92     5.00         3
# 730             2       80        42     5.00         3
# 856          None       74      None     6.00      None
# 875          None       70      None     6.00      None
# 919             2       86        98     5.00         3
# ...           ...      ...       ...      ...       ...
# 1108         None     1251      None     0.50      None
# 1125        1.991       85        62     5.00         3
# 1136         None      138      None     2.50      None
# 1142        0.615      175        72     2.50  0.703125
# 1160            2      117       128     5.00         3
# 1184        1.986       88        59     5.00         3
# 1244        1.989       75        82     5.00         3
# 1276        1.192     1131       111     0.50         3
# 1338        1.989       74        79     5.00         3
# 1340         None       90      None     3.75      None
# 1387        1.998       93        52     5.00         3
# 1456        1.763      458        77     0.50         4
# 1489        1.997       69        77     5.00         3
# 1498        1.997       74        82     5.00         3
# 1501        1.986       74        77     5.00         3
# 1547        1.991     1134        78     0.50         3
# 1680            1      168       184     2.50         2
# 1694        1.107       93       513     5.00       0.5
# 1729            1      155       153     2.50         2
# 1759         None       77      None     6.00      None
# 1825            2       85        88     5.00         3
# 1847        1.991       88        90     5.00         3
# 1874        1.988       85       107     5.00         3
# 1883            2       93       101     5.00         3
# 1890        1.993       90       100     5.00         3
# 1899        1.949       87        41     5.00         3
# 1902        1.991       91        53     5.00         3
# 1968        1.883      129       134     2.00         4
# 1992        1.998       83       142     5.00         2
# 2051         1.99       84        79     5.00         3
#
# [62 rows x 10 columns]

# %%
# print overlaps in 2
display(df_final2[df_final2['ID'].isin(overlaps)].sort_values(by='ID'))

# %% [markdown]
# ### studies in both data dumps have exactly same series selected and the overlap, missing scores are same. So keep the ones in dump2 (local dump)

# %%
# Concatenate Df_final1 and 2 into Df_final

# First remove duplicates in df_final1
df_final1 = df_final1[~df_final1['ID'].isin(overlaps)]
print(len(df_final1))
# Out:
# 1990

# %%
# Remove duplicates in subjects1
subjects1 = [s for s in subjects1 if s.id_ not in overlaps]
print(len(subjects1))
# Out:
# 1990

# %%
# Finally concatenate df_final1 and df_final2, subjects1 and subjects2

df_final1['dump'] = 1
df_final2['dump'] = 2

df_final = df_final1.append(df_final2)
subjects = subjects1 + subjects2

print('Final no of studies: ', len(df_final))
print('Final no of studies: ', len(subjects))

# Remove unwanted
del df_final1
del df_final2
# Out:
# Final no of studies:  2367
# Final no of studies:  2367

# %%
# Save final
save_object(df_final,os.path.join(output,'df_final.pkl'))
save_object(subjects,os.path.join(output,'subjects_final.pkl'))
