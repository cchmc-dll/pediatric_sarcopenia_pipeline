# %% [markdown]
# # Notebook to calculate sarcopenia area for MRI

# %% [markdown]
# ## Import Libraries and Set directories

# %%
#Import Libraries
import os
import SimpleITK as sitk
import pandas as pd
import numpy as np
import re
import matplotlib.figure as figure

from myshow import *

# %%
# Set input/output directories
cwd = os.getcwd()
dir_nifti ='/home/jovyan/data'
dir_output = '/home/jovyan/output'
print(dir_nifti)
print(dir_output)
# Out:
# /home/jovyan/data
# /home/jovyan/output

# %% [markdown]
# ## Define some handy functions for creating dicom

# %%
# load nifti list
patslist = os.listdir(dir_nifti)
pats = [pat for pat in patslist if 'xls' not in pat]
in_file = [pat for pat in patslist if 'xls' in pat][0]
print('No of patient folders to process: ', len(pats))
print('Input Excel file: ', in_file)
# Out:
# No of patient folders to process:  201
# Input Excel file:  sarcopenia data_ES_043021_area_calculation_byLisa.xls

# %%
def get_mask_paths(patpath):
    for root, directories, files in os.walk(patpath):
        for filename in files:
            # join the two strings in order to form the full filepath.
            if 'mask' in filename:
                filepath = os.path.join(root, filename)
                return filepath
            
        print('Nifti mask not found for this patient:', patpath)    
        break

def get_axialmr_paths(patpath):
    for root, directories, files in os.walk(patpath):
        for filename in files:
            # join the two strings in order to form the full filepath.
            if 'Ax' in filename:
                filepath = os.path.join(root, filename)
                return filepath
            
        print('Axial Nifti not foudn for patient:', patpath)    
        break

# %%
# New 
def write_L3_mrandmask(path,pat,out=dir_output):
    # Set paths
    outpath = os.path.join(dir_output,pat)
    os.makedirs(outpath,exist_ok=True)
    inpath = os.path.join(path,pat)
    
    ## Get the 2D mask slice
    maskfile = get_mask_paths(inpath)
    img = sitk.ReadImage(maskfile)

    img_arr = sitk.GetArrayFromImage(img)
    mask_slices = np.unique(np.nonzero(img_arr)[0])
    if len(mask_slices) > 1:
        print('More than 1 axial slice has non zero pixels for pat: ', pat)
    z_loc = mask_slices[0]
    img_2darr = img_arr[z_loc,:,:]
    # Change all labels to skeletal muscle for segmenting both skeletal and psoas together
    img_2darr[img_2darr > 1] = 1
    mask_img = sitk.GetImageFromArray(img_2darr)
    mask_img.SetSpacing(img.GetSpacing()[:-1])
    
    ## Get 2D Axial MR slice at L3
    mrfile = get_axialmr_paths(inpath)
    mrimg = sitk.ReadImage(mrfile)
    mrimg_arr = sitk.GetArrayFromImage(mrimg)
    l3_arr= mrimg_arr[z_loc,:,:]
    l3_arr = l3_arr.astype(np.int16)
    l3_img = sitk.GetImageFromArray(l3_arr)
    l3_img.SetSpacing(mrimg.GetSpacing()[:-1])
    
    ## Resize to 256x256
    new_size = [256,256]
    # Set reference image for resampling
    reference_image = sitk.Image(new_size, l3_img.GetPixelIDValue())
    reference_image.SetOrigin(l3_img.GetOrigin())
    reference_image.SetDirection(l3_img.GetDirection())
    reference_image.SetSpacing([sz*spc/nsz for nsz,sz,spc in zip(new_size, l3_img.GetSize(), mrimg.GetSpacing()[:-1])])    
    #l3_img_smooth = sitk.Resample(sitk.SmoothingRecursiveGaussian(l3_img1[:,:,]), reference_image)
    
    orig_spacing = mrimg.GetSpacing()[0]
    orig_size = l3_img.GetSize()[0]
    l3_img_smooth = sitk.Resample(l3_img, reference_image)
    mask_img_smooth = sitk.Resample(mask_img,reference_image,sitk.TranslationTransform(l3_img.GetDimension()),sitk.sitkNearestNeighbor)
    
    
    # Book Keeping
    orig_spacing = mrimg.GetSpacing()[0]
    orig_size = l3_img.GetSize()[0]
    new_spacing = l3_img_smooth.GetSpacing()[0]
    new_size = l3_img_smooth.GetSize()[0]
    
    ## Write TIF images as output
    print('Pixel Type: ',l3_img_smooth.GetPixelIDTypeAsString())
    sitk.WriteImage(l3_img_smooth, os.path.join(outpath,'MR.tif') )
    sitk.WriteImage(mask_img_smooth, os.path.join(outpath,'MASK.tif') )
    
    return orig_size, orig_spacing, new_size, new_spacing, z_loc

# %%
df = pd.DataFrame(columns = ['pats','slice_no','orig_size','orig_spacing','orig_pixelarea','new_size','new_spacing','new_pixelarea'])
for i,pat in enumerate(reversed(pats)):
    print('processing pat: ',pat)
    orig_size,orig_spacing,new_size,new_spacing,z_loc = write_L3_mrandmask(dir_nifti,pat)
    df.loc[len(df)] = [pat,z_loc,orig_size,orig_spacing,orig_spacing**2,new_size,new_spacing,new_spacing**2]


display(df.head(10))
df.to_csv(os.path.join(dir_output,'image_statistics_resampling.csv'),index=False)
print('all patient processed')
# Out:
# processing pat:  exam 9b
# Pixel Type:  16-bit signed integer
# processing pat:  exam 99
# Pixel Type:  16-bit signed integer
# processing pat:  exam 98
# Pixel Type:  16-bit signed integer
# processing pat:  exam 97b
# Pixel Type:  16-bit signed integer
# processing pat:  exam 96b
# Pixel Type:  16-bit signed integer
# processing pat:  exam 95b
# Pixel Type:  16-bit signed integer
# processing pat:  exam 94b
# Pixel Type:  16-bit signed integer
# processing pat:  exam 93
# Pixel Type:  16-bit signed integer
# processing pat:  exam 92
# Pixel Type:  16-bit signed integer
# processing pat:  exam 91
# Pixel Type:  16-bit signed integer
# processing pat:  exam 90
# Pixel Type:  16-bit signed integer
# processing pat:  exam 89c
# Pixel Type:  16-bit signed integer
# processing pat:  exam 88
# Pixel Type:  16-bit signed integer
# processing pat:  exam 87
# Pixel Type:  16-bit signed integer
# processing pat:  exam 86b
# Pixel Type:  16-bit signed integer
# processing pat:  exam 85
# Pixel Type:  16-bit signed integer
# processing pat:  exam 84
# Pixel Type:  16-bit signed integer
# processing pat:  exam 83
# Pixel Type:  16-bit signed integer
# processing pat:  exam 82
# Pixel Type:  16-bit signed integer
# processing pat:  exam 81
# Pixel Type:  16-bit signed integer
# processing pat:  exam 80b
# Pixel Type:  16-bit signed integer
# processing pat:  exam 8
# Pixel Type:  16-bit signed integer
# processing pat:  exam 79
# Pixel Type:  16-bit signed integer
# processing pat:  exam 78
# Pixel Type:  16-bit signed integer
# processing pat:  exam 77
# Pixel Type:  16-bit signed integer
# processing pat:  exam 76b
# Pixel Type:  16-bit signed integer
# processing pat:  exam 75
# Pixel Type:  16-bit signed integer
# processing pat:  exam 74
# Pixel Type:  16-bit signed integer
# processing pat:  exam 73
# Pixel Type:  16-bit signed integer
# processing pat:  exam 72
# Pixel Type:  16-bit signed integer
# processing pat:  exam 71
# Pixel Type:  16-bit signed integer
# processing pat:  exam 70
# Pixel Type:  16-bit signed integer
# processing pat:  exam 7
# Pixel Type:  16-bit signed integer
# processing pat:  exam 69
# Pixel Type:  16-bit signed integer
# processing pat:  exam 68
# Pixel Type:  16-bit signed integer
# processing pat:  exam 67
# Pixel Type:  16-bit signed integer
# processing pat:  exam 66b
# Pixel Type:  16-bit signed integer
# processing pat:  exam 65
# Pixel Type:  16-bit signed integer
# processing pat:  exam 64
# Pixel Type:  16-bit signed integer
# processing pat:  exam 63
# Pixel Type:  16-bit signed integer
# processing pat:  exam 62
# Pixel Type:  16-bit signed integer
# processing pat:  exam 61
# Pixel Type:  16-bit signed integer
# processing pat:  exam 60
# Pixel Type:  16-bit signed integer
# processing pat:  exam 6
# Pixel Type:  16-bit signed integer
# processing pat:  exam 59
# Pixel Type:  16-bit signed integer
# processing pat:  exam 58
# Pixel Type:  16-bit signed integer
# processing pat:  exam 57
# Pixel Type:  16-bit signed integer
# processing pat:  exam 56
# Pixel Type:  16-bit signed integer
# processing pat:  exam 55
# Pixel Type:  16-bit signed integer
# processing pat:  exam 54
# Pixel Type:  16-bit signed integer
# processing pat:  exam 53
# Pixel Type:  16-bit signed integer
# processing pat:  exam 52
# Pixel Type:  16-bit signed integer
# processing pat:  exam 51
# Pixel Type:  16-bit signed integer
# processing pat:  exam 50
# Pixel Type:  16-bit signed integer
# processing pat:  exam 5
# Pixel Type:  16-bit signed integer
# processing pat:  exam 49
# Pixel Type:  16-bit signed integer
# processing pat:  exam 48
# Pixel Type:  16-bit signed integer
# processing pat:  exam 47
# Pixel Type:  16-bit signed integer
# processing pat:  exam 46
# Pixel Type:  16-bit signed integer
# processing pat:  exam 45
# Pixel Type:  16-bit signed integer
# processing pat:  exam 44
# Pixel Type:  16-bit signed integer
# processing pat:  exam 43
# Pixel Type:  16-bit signed integer
# processing pat:  exam 42
# Pixel Type:  16-bit signed integer
# processing pat:  exam 41
# Pixel Type:  16-bit signed integer
# processing pat:  exam 40
# Pixel Type:  16-bit signed integer
# processing pat:  exam 4
# Pixel Type:  16-bit signed integer
# processing pat:  exam 39
# Pixel Type:  16-bit signed integer
# processing pat:  exam 38
# Pixel Type:  16-bit signed integer
# processing pat:  exam 37
# Pixel Type:  16-bit signed integer
# processing pat:  exam 36
# Pixel Type:  16-bit signed integer
# processing pat:  exam 35
# Pixel Type:  16-bit signed integer
# processing pat:  exam 34
# Pixel Type:  16-bit signed integer
# processing pat:  exam 33
# Pixel Type:  16-bit signed integer
# processing pat:  exam 32
# Pixel Type:  16-bit signed integer
# processing pat:  exam 31
# Pixel Type:  16-bit signed integer
# processing pat:  exam 30
# Pixel Type:  16-bit signed integer
# processing pat:  exam 3
# Pixel Type:  16-bit signed integer
# processing pat:  exam 29
# Pixel Type:  16-bit signed integer
# processing pat:  exam 28
# Pixel Type:  16-bit signed integer
# processing pat:  exam 27
# Pixel Type:  16-bit signed integer
# processing pat:  exam 26
# Pixel Type:  16-bit signed integer
# processing pat:  exam 25b
# Pixel Type:  16-bit signed integer
# processing pat:  exam 24
# Pixel Type:  16-bit signed integer
# processing pat:  exam 23
# Pixel Type:  16-bit signed integer
# processing pat:  exam 220
# Pixel Type:  16-bit signed integer
# processing pat:  exam 22
# Pixel Type:  16-bit signed integer
# processing pat:  exam 219
# Pixel Type:  16-bit signed integer
# processing pat:  exam 218
# Pixel Type:  16-bit signed integer
# processing pat:  exam 217
# Pixel Type:  16-bit signed integer
# processing pat:  exam 215
# Pixel Type:  16-bit signed integer
# processing pat:  exam 214
# Pixel Type:  16-bit signed integer
# processing pat:  exam 212
# Pixel Type:  16-bit signed integer
# processing pat:  exam 210
# Pixel Type:  16-bit signed integer
# processing pat:  exam 21
# Pixel Type:  16-bit signed integer
# processing pat:  exam 208
# Pixel Type:  16-bit signed integer
# processing pat:  exam 207
# Pixel Type:  16-bit signed integer
# processing pat:  exam 204
# Pixel Type:  16-bit signed integer
# processing pat:  exam 203
# Pixel Type:  16-bit signed integer
# processing pat:  exam 202
# Pixel Type:  16-bit signed integer
# processing pat:  exam 200
# Pixel Type:  16-bit signed integer
# processing pat:  exam 20
# Pixel Type:  16-bit signed integer
# processing pat:  exam 2
# Pixel Type:  16-bit signed integer
# processing pat:  exam 198
# Pixel Type:  16-bit signed integer
# processing pat:  exam 196
# Pixel Type:  16-bit signed integer
# processing pat:  exam 194
# Pixel Type:  16-bit signed integer
# processing pat:  exam 193
# Pixel Type:  16-bit signed integer
# processing pat:  exam 192
# Pixel Type:  16-bit signed integer
# processing pat:  exam 19
# Pixel Type:  16-bit signed integer
# processing pat:  exam 189
# Pixel Type:  16-bit signed integer
# processing pat:  exam 188
# Pixel Type:  16-bit signed integer
# processing pat:  exam 186
# Pixel Type:  16-bit signed integer
# processing pat:  exam 185
# Pixel Type:  16-bit signed integer
# processing pat:  exam 182
# Pixel Type:  16-bit signed integer
# processing pat:  exam 181
# Pixel Type:  16-bit signed integer
# processing pat:  exam 180
# Pixel Type:  16-bit signed integer
# processing pat:  exam 18
# Pixel Type:  16-bit signed integer
# processing pat:  exam 177
# Pixel Type:  16-bit signed integer
# processing pat:  exam 176
# Pixel Type:  16-bit signed integer
# processing pat:  exam 175
# Pixel Type:  16-bit signed integer
# processing pat:  exam 174
# Pixel Type:  16-bit signed integer
# processing pat:  exam 173
# Pixel Type:  16-bit signed integer
# processing pat:  exam 172
# Pixel Type:  16-bit signed integer
# processing pat:  exam 171
# Pixel Type:  16-bit signed integer
# processing pat:  exam 170
# Pixel Type:  16-bit signed integer
# processing pat:  exam 17
# Pixel Type:  16-bit signed integer
# processing pat:  exam 169
# Pixel Type:  16-bit signed integer
# processing pat:  exam 167
# Pixel Type:  16-bit signed integer
# processing pat:  exam 166
# Pixel Type:  16-bit signed integer
# processing pat:  exam 165
# Pixel Type:  16-bit signed integer
# processing pat:  exam 164
# Pixel Type:  16-bit signed integer
# processing pat:  exam 163
# Pixel Type:  16-bit signed integer
# processing pat:  exam 162b
# Pixel Type:  16-bit signed integer
# processing pat:  exam 161
# Pixel Type:  16-bit signed integer
# processing pat:  exam 160
# Pixel Type:  16-bit signed integer
# processing pat:  exam 16
# Pixel Type:  16-bit signed integer
# processing pat:  exam 159
# Pixel Type:  16-bit signed integer
# processing pat:  exam 158
# Pixel Type:  16-bit signed integer
# processing pat:  exam 157
# Pixel Type:  16-bit signed integer
# processing pat:  exam 156b
# Pixel Type:  16-bit signed integer
# processing pat:  exam 155
# Pixel Type:  16-bit signed integer
# processing pat:  exam 154
# Pixel Type:  16-bit signed integer
# processing pat:  exam 153
# Pixel Type:  16-bit signed integer
# processing pat:  exam 152b
# Pixel Type:  16-bit signed integer
# processing pat:  exam 151
# Pixel Type:  16-bit signed integer
# processing pat:  exam 150b
# Pixel Type:  16-bit signed integer
# processing pat:  exam 15
# Pixel Type:  16-bit signed integer
# processing pat:  exam 148b
# Pixel Type:  16-bit signed integer
# processing pat:  exam 147b
# Pixel Type:  16-bit signed integer
# processing pat:  exam 146
# Pixel Type:  16-bit signed integer
# processing pat:  exam 145
# Pixel Type:  16-bit signed integer
# processing pat:  exam 144b
# Pixel Type:  16-bit signed integer
# processing pat:  exam 143
# Pixel Type:  16-bit signed integer
# processing pat:  exam 142
# Pixel Type:  16-bit signed integer
# processing pat:  exam 141b
# Pixel Type:  16-bit signed integer
# processing pat:  exam 140
# Pixel Type:  16-bit signed integer
# processing pat:  exam 14
# Pixel Type:  16-bit signed integer
# processing pat:  exam 139
# Pixel Type:  16-bit signed integer
# processing pat:  exam 138
# Pixel Type:  16-bit signed integer
# processing pat:  exam 137
# Pixel Type:  16-bit signed integer
# processing pat:  exam 136
# Pixel Type:  16-bit signed integer
# processing pat:  exam 135
# Pixel Type:  16-bit signed integer
# processing pat:  exam 134b
# Pixel Type:  16-bit signed integer
# processing pat:  exam 133
# Pixel Type:  16-bit signed integer
# processing pat:  exam 132
# Pixel Type:  16-bit signed integer
# processing pat:  exam 131
# Pixel Type:  16-bit signed integer
# processing pat:  exam 130
# Pixel Type:  16-bit signed integer
# processing pat:  exam 13
# Pixel Type:  16-bit signed integer
# processing pat:  exam 129
# Pixel Type:  16-bit signed integer
# processing pat:  exam 128
# Pixel Type:  16-bit signed integer
# processing pat:  exam 127
# Pixel Type:  16-bit signed integer
# processing pat:  exam 126
# Pixel Type:  16-bit signed integer
# processing pat:  exam 125
# Pixel Type:  16-bit signed integer
# processing pat:  exam 124
# Pixel Type:  16-bit signed integer
# processing pat:  exam 123b
# Pixel Type:  16-bit signed integer
# processing pat:  exam 122
# Pixel Type:  16-bit signed integer
# processing pat:  exam 121
# Pixel Type:  16-bit signed integer
# processing pat:  exam 120
# Pixel Type:  16-bit signed integer
# processing pat:  exam 12
# Pixel Type:  16-bit signed integer
# processing pat:  exam 119
# Pixel Type:  16-bit signed integer
# processing pat:  exam 118
# Pixel Type:  16-bit signed integer
# processing pat:  exam 117b
# Pixel Type:  16-bit signed integer
# processing pat:  exam 116
# Pixel Type:  16-bit signed integer
# processing pat:  exam 115
# Pixel Type:  16-bit signed integer
# processing pat:  exam 114
# Pixel Type:  16-bit signed integer
# processing pat:  exam 113
# Pixel Type:  16-bit signed integer
# processing pat:  exam 112
# Pixel Type:  16-bit signed integer
# processing pat:  exam 111b
# Pixel Type:  16-bit signed integer
# processing pat:  exam 110
# Pixel Type:  16-bit signed integer
# processing pat:  exam 11
# Pixel Type:  16-bit signed integer
# processing pat:  exam 109c
# Pixel Type:  16-bit signed integer
# processing pat:  exam 108
# Pixel Type:  16-bit signed integer
# processing pat:  exam 107
# Pixel Type:  16-bit signed integer
# processing pat:  exam 106
# Pixel Type:  16-bit signed integer
# processing pat:  exam 105
# Pixel Type:  16-bit signed integer
# processing pat:  exam 104b
# Pixel Type:  16-bit signed integer
# processing pat:  exam 103
# Pixel Type:  16-bit signed integer
# processing pat:  exam 102
# Pixel Type:  16-bit signed integer
# processing pat:  exam 101
# Pixel Type:  16-bit signed integer
# processing pat:  exam 100
# Pixel Type:  16-bit signed integer
# processing pat:  exam 10
# Pixel Type:  16-bit signed integer
# processing pat:  exam 1
# Pixel Type:  16-bit signed integer
#        pats slice_no orig_size  orig_spacing  orig_pixelarea new_size  \
# 0   exam 9b       36       512      0.781300        0.610430      256
# 1   exam 99       10       512      0.664100        0.441029      256
# 2   exam 98       45       320      0.781250        0.610352      256
# 3  exam 97b       34       512      0.546900        0.299100      256
# 4  exam 96b       38       512      0.546900        0.299100      256
# 5  exam 95b       40       512      0.585900        0.343279      256
# 6  exam 94b       56       352      0.909091        0.826446      256
# 7   exam 93       43       320      0.812500        0.660156      256
# 8   exam 92       16       512      0.703100        0.494350      256
# 9   exam 91       38       384      0.781250        0.610352      256
#
#    new_spacing  new_pixelarea
# 0     1.562600       2.441719
# 1     1.328200       1.764115
# 2     0.976562       0.953674
# 3     1.093800       1.196398
# 4     1.093800       1.196398
# 5     1.171800       1.373115
# 6     1.250000       1.562500
# 7     1.015625       1.031494
# 8     1.406200       1.977399
# 9     1.171875       1.373291
# all patient processed
